# %%
# %run "/Users/manasadevi.j@diggibyte.com/DATABRICKS-ASSIGNMENTS/src/Question-1/source_to_bronze/utils"

# %%
# Read raw files
employee_df = read_csv("/Volumes/workspace/assignments/dev_catalog/bronze/Employee-Q1.csv")
department_df = read_csv("/Volumes/workspace/assignments/dev_catalog/bronze/Department-Q1.csv")
country_df = read_csv("/Volumes/workspace/assignments/dev_catalog/bronze/Country-Q1.csv")

# Validate
display(employee_df)
display(department_df)
display(country_df)

# Write to bronze structured paths (assignment requirement)
write_csv(employee_df, "/Volumes/workspace/assignments/dev_catalog/bronze/employee")
write_csv(department_df, "/Volumes/workspace/assignments/dev_catalog/bronze/department")
write_csv(country_df, "/Volumes/workspace/assignments/dev_catalog/bronze/country")
